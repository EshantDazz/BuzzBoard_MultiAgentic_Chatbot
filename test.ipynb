# %%
import pandas as pd
df=pd.read_excel("Data/Sample Data for the Model.xlsx")

# %%
import pandas as pd

# Read the Excel file, skipping the 1st and 3rd rows, and using the 2nd row as the header
df = pd.read_excel("Data/Sample Data for the Model.xlsx", skiprows=[0, 2])

# %%
df.head()
# Out:
#        Customer                                           Products User Name  \
# 0  Acme Digital  Website Design Services\n1. Responsive Design:...  John Doe
# 1           NaN                                                NaN  John Doe
# 2           NaN                                                NaN  John Doe
# 3           NaN  Email and Microsoft 365\n1. Microsoft 365 Desk...    Mathew
# 4           NaN                                                NaN    Mathew
#
#                         UID             Business Name  \
# 0  5387439f2f92e2af1a401a9c       TagLine Media Group
# 1  538746be2f92e2af1a4a2612  Insight Marketing Design
# 2  538749ed2f92e2af1a53da57           Agency Creative
# 3  538754b42f92e2af1a75d02c               Madisonmain
# 4  538756b32f92e2af1a7c24dd                 Geonetric
#
#                          Address State          City    Zip       Phone  ...  \
# 0                1655 N Swan Rd,    AZ        Tucson  85712  5202078910  ...
# ...

# %%
df['All Signals.2']
# Out:
# 0     [{"BUSINESS INFO":{"Business Name":"Madden Med...
# 1     [{"BUSINESS INFO":{"Business Name":"Tiger29","...
# 2     [{"BUSINESS INFO":{"Business Name":"Miller Ad ...
# 3     [{"BUSINESS INFO":{"Business Name":"Practice P...
# 4     [{"BUSINESS INFO":{"Business Name":"Vortex Bus...
# 5     [{"BUSINESS INFO":{"Business Name":"Thrive Int...
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# Name: All Signals.2, dtype: object

# %%
data=[{"BUSINESS INFO":{"Business Name":"Jackrabbit","Website Formatted":"http://jackrabbitmobile.com","Website":"http://jackrabbitmobile.com","Phone":"5122538083","Default Email":"hello@jackrabbitmobile.com","Email List":["hello@jackrabbitmobile.com"],"street_address":"4301 W William Cannon Dr Ste B-150","city":"Austin","zip":"78749","state":"TX","country":"United States","Headquarters":"Yes","BuzzScore":78},"CATEGORY":{"primarry_category_name":"Contractors - Computer","secondary_category_name":"Contractors - Computer"},"FIRMOGRAPHICS":{"locations_count":2,"annual_revenue":"$10M - $25M","monthly_technology_spend":"474","revenue_seasonality":"Fall, Winter","remote_only_business":"No"},"E-Commerce":{"reviews":"Yes","featured_products":"No","promotions":"No","coupons":"No","wish_list":"No","order_tracking":"No","get_a_quote":"Yes","scheduler":"Yes","mortgage_calculator":"No","finance":"No","inventory_search_form":"No","estimates_page":"No","menu":"No","facebook_shop_presence":"No","amazon_page_presence":"No","reservation_and_booking":"Yes","online_ordering":"No","buying_page":"No","selling_page":"No","rentals_page":"No"},"Multi-Screen Compatibility":{"Mobile-Friendly":"Yes","Responsive Design":"Yes","Page Speed Score (Mobile)":37},"Advertising":{"Google Ads":"Yes","Display Ads":"No","Facebook Ads":"No","Yelp Ads":"No"},"Social Media Presence":{"facebook_business_page- presence":"Yes","facebook_business_page- fb_followers":"2,000","facebook_business_page- page_url":"https://facebook.com/pg/254698787970329","youtube_business_channel- presence":"Yes","youtube_business_channel- yt_videos_counts":"31","youtube_business_channel- yt_subscribers_counts":"26","youtube_business_channel- yt_views_counts":"18.9K","youtube_business_channel- page_url":"https://www.youtube.com/channel/UC9vzYp97QlpOfPhPef4EP3w","linkedin_company_profile- presence":"Yes","linkedin_company_profile- page_url":"https://www.linkedin.com/company/jackrabbit-mobile","pinterest- presence":"No","instagram- presence":"Yes","instagram- insta_posts":"25","instagram- insta_followers":"78","instagram- insta_following":"22","instagram- page_url":"https://www.instagram.com/jackrabbitmobile","fb_fans- Facebook Likes":"2,086","fbcheckins- Facebook Check ins":"103","pinterest_domain_verified- Pinterest Domain Verified":"No","pinterest_is_verified_merchant- Pinterest Verified Merchant":"No"},"Local Business Presence":{"google_places-Listed":"Yes","google_places-Claimed":"Yes","google_places-NAP":"No","google_places-local_directory_googleplaces_reviews":"149","google_places-local_directory_googleplaces_ratings":"4.7","yelp-Listed":"Yes","yelp-Claimed":"Yes","yelp-NAP":"No","yelp-local_directory_yelp_reviews":"No","yelp-local_directory_yelp_ratings":"4.1","yellow_pages-Listed":"Yes","yellow_pages-Claimed":"No","yellow_pages-NAP":"No","nokia_places-Listed":"No","nokia_places-Claimed":"No","nextdoor-Listed":"No","nextdoor-Claimed":"No","google_places_claimed-Claimed":"Yes","yelp_claimed-Claimed":"Yes","yellow_pages_climed-Claimed":"No","nokia_places_climed-Claimed":"No"},"Marketplace":{"Thumbtack":"No","Uber Eats":"No","OpenTable":"No","iOS App":"No","Android App":"No"},"Content Analysis":{"Local Phone Number":"No","Address on Homepage":"No","Map & Directions":"No","Contact Us":"No","Privacy Policy":"No","About Page":"No","Services Page":"No","Newsletter":"No"},"Infrastructure Robustness":{"PageSpeed Score (Desktop)":"74","Caching Enabled":2,"Image Size Optimization":2,"Text Compression":"No","Server Response Time":"0.061 s","No Page Redirects":"Yes","Prioritize Visible Content":2,"Wordpress":"Yes","Google Analytics":"Yes","SSL":"Yes"},"Google Reviews":{"Negative":"No","Neutral":"No","Positive":"100%"},"HR & Organization":{"Employee Count":"51 - 100","Employee Reviews":"No","Employee Ratings":"No","Open Positions":"No"},"SEO Analysis":{"Domain Redirection":"Yes","Robots.txt":"Yes","Sitemap.xml":"Yes","Title Tag Compliance":"Yes","Location In Title":"Yes","Unique Title":"Yes","Meta Description Compliance":"Yes","Headings Included":"Yes","Image Alt Text":"Yes","Frames Excluded":"Yes","Flash Excluded":"Yes","Backlinks":"Yes","Domain Authority":"No","Domain Age":"12 Y, 4 M","Rich Snippets":"No","SEF URL":"Yes","Sitemap.html":"No","Trust Flow Score":"7"}}]

# %%
result=data[0]

# %%
result
# Out:
# {'BUSINESS INFO': {'Business Name': 'Jackrabbit',
#   'Website Formatted': 'http://jackrabbitmobile.com',
#   'Website': 'http://jackrabbitmobile.com',
#   'Phone': '5122538083',
#   'Default Email': 'hello@jackrabbitmobile.com',
#   'Email List': ['hello@jackrabbitmobile.com'],
#   'street_address': '4301 W William Cannon Dr Ste B-150',
#   'city': 'Austin',
#   'zip': '78749',
#   'state': 'TX',
#   'country': 'United States',
#   'Headquarters': 'Yes',
#   'BuzzScore': 78},
#  'CATEGORY': {'primarry_category_name': 'Contractors - Computer',
#   'secondary_category_name': 'Contractors - Computer'},
#  'FIRMOGRAPHICS': {'locations_count': 2,
#   'annual_revenue': '$10M - $25M',
#   'monthly_technology_spend': '474',
#   'revenue_seasonality': 'Fall, Winter',
#   'remote_only_business': 'No'},
#  'E-Commerce': {'reviews': 'Yes',
#   'featured_products': 'No',
#   'promotions': 'No',
#   'coupons': 'No',
#   'wish_list': 'No',
#   'order_tracking': 'No',
#   'get_a_quote': 'Yes',
# ...

# %%
df=pd.read_excel("Data/Sample Data for the Model.xlsx",skiprows=[0])

# %%
df.head(9)
# Out:
#                Customer                                           Products  \
# 0              Customer     Products offered in the Market by the Customer
# 1          Acme Digital  Website Design Services\n1. Responsive Design:...
# 2                   NaN                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN  Email and Microsoft 365\n1. Microsoft 365 Desk...
# 5                   NaN                                                NaN
# 6                   NaN                                                NaN
# 7  Hiwire Digital Media  O&O Audience: \n   - Where businesses wield fu...
# 8                   NaN                                                NaN
#
#                    User Name                       UID  \
# 0  Sales Rep of the Customer                       UID
# 1                   John Doe  5387439f2f92e2af1a401a9c
# ...

# %%
import pandas as pd

# Load the Excel file
file_path = "Data/Sample Data for the Model.xlsx"  # Replace with the actual path to your file
data_sheet_full = pd.read_excel(file_path, header=None)

# Identify all columns related to "All Signals"
# Assumes the second row (index 1) contains column headers
all_signals_columns = data_sheet_full.columns[
    data_sheet_full.iloc[1].str.contains("All Signals", case=False, na=False)
]

# Extract rows for these columns
all_signals_data = data_sheet_full.loc[:, all_signals_columns]

# Save the extracted data to a new file for review
output_file_path = "all_signals_data.xlsx"  # Save it as Excel
all_signals_data.to_excel(output_file_path, index=False)

print(f"Data extracted and saved to: {output_file_path}")
# Out:
# Data extracted and saved to: all_signals_data.xlsx

# %%
import pandas as pd
df=pd.read_excel("all_signals_data.xlsx",skiprows=[0,1])
df.head()
# Out:
#                          All Signals/SMB Data Points  \
# 0                                                NaN
# 1  [{"BUSINESS INFO":{"Business Name":"TagLine Me...
# 2  [{"BUSINESS INFO":{"Business Name":"Insight Ma...
# 3  [{"BUSINESS INFO":{"Business Name":"Agency Cre...
# 4  [{"BUSINESS INFO":{"Business Name":"Madisonmai...
#
#                                          All Signals  \
# 0                                       Competition1
# 1  [{"BUSINESS INFO":{"Business Name":"Intoclicks...
# 2  [{"BUSINESS INFO":{"Business Name":"Marketbeat...
# 3  [{"BUSINESS INFO":{"Business Name":"Spectrum R...
# 4  [{"BUSINESS INFO":{"Business Name":"Ooh Lamar ...
#
#                                        All Signals.1  \
# 0                                       Competition2
# 1  [{"BUSINESS INFO":{"Business Name":"Gsm Market...
# 2  [{"BUSINESS INFO":{"Business Name":"Click Rain...
# 3  [{"BUSINESS INFO":{"Business Name":"On Hold So...
# ...

# %%
columns=df.columns

# %%
for i in columns:
    print(i)
# Out:
# All Signals/SMB Data Points
# All Signals
# All Signals.1
# All Signals.2

# %%
df.isnull().sum()
# Out:
# All Signals/SMB Data Points    1
# All Signals                    0
# All Signals.1                  0
# All Signals.2                  6
# dtype: int64

# %%
df.shape
# Out:
# (13, 4)

# %%
# Take the first 3 rows and convert to JSON
json_result = df.head(5).to_json(orient='records')

print(json_result)
# Out:
# [{"All Signals\/SMB Data Points":null,"All Signals":"Competition1","All Signals.1":"Competition2","All Signals.2":"Competition3"},{"All Signals\/SMB Data Points":"[{\"BUSINESS INFO\":{\"Business Name\":\"TagLine Media Group\",\"Website Formatted\":\"http:\/\/taglinegroup.com\/\",\"Website\":\"http:\/\/taglinegroup.com\/\",\"Phone\":\"5202078910\",\"Default Email\":\"mc@taglinegroup.com\",\"Email List\":[\"mc@taglinegroup.com\"],\"street_address\":\"1655 N Swan Rd,\",\"city\":\"Tucson\",\"zip\":\"85712\",\"state\":\"AZ\",\"country\":\"United States\",\"Headquarters\":\"No\",\"BuzzScore\":74},\"CATEGORY\":{\"primarry_category_name\":\"Advertising\",\"secondary_category_name\":\"Advertising Agencies\"},\"FIRMOGRAPHICS\":{\"locations_count\":1,\"annual_revenue\":\"$1M - $ 2.5M\",\"monthly_technology_spend\":\"700\",\"revenue_seasonality\":\"Fall, Winter\",\"remote_only_business\":\"No\"},\"E-Commerce\":{\"reviews\":\"Yes\",\"featured_products\":\"No\",\"promotions\":\"No\",\"coupons\":\"
# ...

# %%
json_result
# Out:
# '[{"All Signals\\/SMB Data Points":null,"All Signals":"Competition1","All Signals.1":"Competition2","All Signals.2":"Competition3"},{"All Signals\\/SMB Data Points":"[{\\"BUSINESS INFO\\":{\\"Business Name\\":\\"TagLine Media Group\\",\\"Website Formatted\\":\\"http:\\/\\/taglinegroup.com\\/\\",\\"Website\\":\\"http:\\/\\/taglinegroup.com\\/\\",\\"Phone\\":\\"5202078910\\",\\"Default Email\\":\\"mc@taglinegroup.com\\",\\"Email List\\":[\\"mc@taglinegroup.com\\"],\\"street_address\\":\\"1655 N Swan Rd,\\",\\"city\\":\\"Tucson\\",\\"zip\\":\\"85712\\",\\"state\\":\\"AZ\\",\\"country\\":\\"United States\\",\\"Headquarters\\":\\"No\\",\\"BuzzScore\\":74},\\"CATEGORY\\":{\\"primarry_category_name\\":\\"Advertising\\",\\"secondary_category_name\\":\\"Advertising Agencies\\"},\\"FIRMOGRAPHICS\\":{\\"locations_count\\":1,\\"annual_revenue\\":\\"$1M - $ 2.5M\\",\\"monthly_technology_spend\\":\\"700\\",\\"revenue_seasonality\\":\\"Fall, Winter\\",\\"remote_only_business\\":\\"No\\"},\\"E-Comme
# ...

# %%
import json

# %%
# Write the JSON to a file with indent=4
with open('output.json', 'w') as file:
    json.dump(json.loads(json_result), file, indent=4)

print("JSON data has been written to 'output.json'")
# Out:
# JSON data has been written to 'output.json'
